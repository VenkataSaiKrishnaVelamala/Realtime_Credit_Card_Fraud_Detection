# %%
! pip install pymongo

# %%
! pip install dnspython

# %%
! pip3 install boto3
# Out:
# ...
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/a3/09/225d978bbe08b3c7b916732dbd7c65c03d4d89d47ea04df7fc0d149738fd/boto3-1.34.63-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for botocore<1.35.0,>=1.34.63 from https://files.pythonhosted.org/packages/ed/1b/1e150fa8bc26ab8114eb42715e97c832522da1b227c8b224f2206949368d/botocore-1.34.63-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/83/37/395cdb6ee92925fa211e55d8f07b9f93cf93f60d7d4ce5e66fd73f1ea986/s3transfer-0.10.1-py3-none-any.whl.metadata
# ...

# %%
! python -m pip install "pymongo[srv]"==3.6

# %%
import boto3
from pymongo import MongoClient
from bson.json_util import dumps


print("hello")
# MongoDB setup
mongo_client = MongoClient('mongodb+srv://<vvsk2001>:<test12345>@cluster0.uehkobv.mongodb.net/',  tlsAllowInvalidCertificates=True)
db = mongo_client['credit_card']
collection = db['fraud_transactions']

print("hello2")
# AWS Kinesis setup
#kinesis_client = boto3.client('kinesis', region_name='us-east-1',
#                              aws_access_key_id='AKIATN4HIWWEIVB4II6K',
#                              aws_secret_access_key='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')


print("hello4")
# Stream name
stream_name = 'credit_card_fraud'

# Read data from MongoDB
for document in collection.find():
    # Convert MongoDB document to JSON
    #document_json = dumps(document)
    # Send data to Kinesis
    print(document)
    #kinesis_client.put_record(StreamName=stream_name,
    #                          Data=document_json,
    #                          PartitionKey='cardnumber')
# Out:
# hello
# hello2
# hello4
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[18], line 24
#      21 stream_name = 'credit_card_fraud'
#      23 # Read data from MongoDB
# ---> 24 for document in collection.find():
#      25     # Convert MongoDB document to JSON
#      26     #document_json = dumps(document)
#      27     # Send data to Kinesis
#      28     print(document)
#      29     #kinesis_client.put_record(StreamName=stream_name,
#      30     #                          Data=document_json,
#      31     #                          PartitionKey='cardnumber')
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# ...

# %%
import pymongo

# %%
import requests
import json
url = "https://us-west-2.aws.data.mongodb-api.com/app/data-gnmow/endpoint/data/v1/action/findOne"

payload = json.dumps({
    "collection": "fraud_transactions",
    "database": "credit_card",
    "dataSource": "Cluster0",
    "projection": {
        
    }
})
headers = {
  'Content-Type': 'application/json',
  'Access-Control-Request-Headers': '*',
  'api-key': 'y2jAERXaIa7VTGVR02y0piLAurRi3qELEtyr10Ny1S3ymxR6YhZUcbuWhZSBssLs',
}

while True:
    response = requests.request("POST", url, headers=headers, data=payload)

    print(response.text)
# Out:
# {"document":{"_id":"65f417687599d4177589ae92","cardnumber":"4328522585475199899","Amount":671.04,"City":"New Jillmouth","State":"OK","merchant":"Cook, Tanner and Orozco"}}
# {"document":{"_id":"65f417687599d4177589ae92","cardnumber":"4328522585475199899","Amount":671.04,"City":"New Jillmouth","State":"OK","merchant":"Cook, Tanner and Orozco"}}
# {"document":{"_id":"65f417687599d4177589ae92","cardnumber":"4328522585475199899","Amount":671.04,"City":"New Jillmouth","State":"OK","merchant":"Cook, Tanner and Orozco"}}
# {"document":{"_id":"65f417687599d4177589ae92","cardnumber":"4328522585475199899","Amount":671.04,"City":"New Jillmouth","State":"OK","merchant":"Cook, Tanner and Orozco"}}
# {"document":{"_id":"65f417687599d4177589ae92","cardnumber":"4328522585475199899","Amount":671.04,"City":"New Jillmouth","State":"OK","merchant":"Cook, Tanner and Orozco"}}
# ...

# %%
import requests
import json

url = "https://us-west-2.aws.data.mongodb-api.com/app/data-gnmow/endpoint/data/v1/action/findMany"  # Hypothetical endpoint
api_key = "your_api_key_here"  # Replace with your actual API key

headers = {
    'Content-Type': 'application/json',
    'Access-Control-Request-Headers': '*',
    'api-key': "y2jAERXaIa7VTGVR02y0piLAurRi3qELEtyr10Ny1S3ymxR6YhZUcbuWhZSBssLs",
}

payload_template = {
    "collection": "fraud_transactions",
    "database": "credit_card",
    "dataSource": "Cluster0",
    "filter": {},  # Your filter criteria here, empty for all documents  # Pagination 
    "limit" : 100
}

# Initialize pagination variables
page = 0
limit = payload_template["limit"]
total_documents_fetched = 0

# Loop until break
while True:
    payload = json.dumps(payload_template)
    response = requests.post(url, headers=headers, data=payload)
    if response.status_code != 200:
        print("Error fetching data:", response.text)
        break
    
    data = response.json()
    documents = data.get("documents", [])
    
    if not documents:
        print("No more documents to fetch.")
        break
    
    # Process your documents here
    for document in documents:
        print(document)  # Example processing
    
    total_documents_fetched += len(documents)
    print(f"Total documents fetched: {total_documents_fetched}")
    
    # Update pagination variables if necessary
    # This depends on how the API lets you request the next set of documents
    page += 1  # Hypothetical page increment
# Out:
# Error fetching data: {"error":"endpoint 'POST /data/v1/action/findMany' not found","error_code":"EndpointNotFound","link":"https://services.cloud.mongodb.com/groups/65f405bcc4d1ef0e841712d4/apps/65f48b0270fc203946e61277/logs?co_id=65f48de2080ba00e735680a9"}

# %%
! pip install python certifi
# Out:
# ERROR: Could not find a version that satisfies the requirement python (from versions: none)
# ERROR: No matching distribution found for python

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://<vvsk2001>:<d9UY6zbRBsavIlJI>@cluster0.uehkobv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ac-ukex7jm-shard-00-01.uehkobv.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-ukex7jm-shard-00-00.uehkobv.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-ukex7jm-shard-00-02.uehkobv.mongodb.net:27017: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65f44822b83b015f861e9c27, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-ukex7jm-shard-00-00.uehkobv.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ac-ukex7jm-
# ...

# %%
import pymongo

# %%
from pymongo.mongo_client import MongoClient



auth_database = "admin"  # The database to authenticate against, typically "admin"
auth_mechanism = "SCRAM-SHA-256"

uri = "mongodb+srv://vvsk2001:d9UY6zbRBsavIlJI@cluster0.uehkobv.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0&authSource={auth_database}&authMechanism={auth_mechanism}"

# Create a new client and connect to the server
client = MongoClient(uri,  tlsAllowInvalidCertificates=True)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/uri_parser.py:321: UserWarning: authmechanism must be in ('SCRAM-SHA-256', 'MONGODB-X509', 'PLAIN', 'MONGODB-CR', 'GSSAPI', 'MONGODB-OIDC', 'MONGODB-AWS', 'SCRAM-SHA-1', 'DEFAULT')
#   return get_validated_options(opts, warn)
# Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1710526840, 1), 'signature': {'hash': b'q\xf9e\x06\x16s\xb2\xee_\x92\x9a\xcc\x9e\xb0\xcb\xb7\x10\x85\x82.', 'keyId': 7346538634935271429}}, 'operationTime': Timestamp(1710526840, 1)}

# %%
from pymongo import MongoClient

# Replace this with your actual connection string copied from MongoDB Atlas
# Make sure to replace <password> with your actual password
connection_string = "mongodb+srv://vvsk2001:d9UY6zbRBsavIlJI@cluster0.uehkobv.mongodb.net/"

# Connect to your MongoDB cluster
client = MongoClient(connection_string,tlsAllowInvalidCertificates=True)

# Specify the database and collection
db = client['credit_card']
collection = db['fraud_transactions']

# Perform a simple find operation to test the connection
for document in collection.find():
    print(document)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[26], line 15
#      12 collection = db['fraud_transactions']
#      14 # Perform a simple find operation to test the connection
# ---> 15 for document in collection.find():
#      16     print(document)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/cursor.py:1264, in Cursor.next(self)
#    1262 if self.__empty:
#    1263     raise StopIteration
# -> 1264 if len(self.__data) or self._refresh():
#    1265     return self.__data.popleft()
#    1266 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pymongo/cursor.py:1181, in Cursor._refresh(self)
#    1159         raise InvalidOperation(
#    1160             "Passing a 'hint' is required when using the min/max query"
# ...
